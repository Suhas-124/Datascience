# %% [markdown]
# ## Bivariate/Multivariate
#
# Analysis of two columns is bivariate.
# Analysis of more than two columns is multivariate.

# %% [markdown]
# | Feature Relationship     | Plot Types                                |
# |--------------------------|-------------------------------------------|
# | Numerical-Numerical      | Scatter Plot, Line Plot, Hexbin Plot, Density Plot,KDE Plot |
# | Numerical-Categorical    | Bar Plot, Box Plot, Violin Plot, Swarm Plot |
# | Categorical-Categorical  | Heatmap, Cluster Map, Mosaic Plot, Grouped Bar Plot,Pair Plot(all details in one) |

# %% [markdown]
# ## 💡 **What is Bivariate Analysis?**
# **Bivariate analysis** means analyzing the relationship between **two variables** to find patterns, correlations, or differences.
#
# - **Example:** Is there a relationship between **age** and **salary**?
# - **Types of variables:**
#   - **Numerical ↔ Numerical** (e.g., Age vs. Salary)
#   - **Categorical ↔ Numerical** (e.g., Gender vs. Income)
#   - **Categorical ↔ Categorical** (e.g., Gender vs. Preferred Product)
#
#
# ## 🧩 **Steps to Perform Bivariate Analysis (General Procedure)**
#
# ### ✅ **Step 1: Understand the Data Types**
# First, figure out whether the variables are **numerical** or **categorical**.
#
# 👉 Example dataset:
#
# | Age   | Salary   | Gender | Purchased |
# |-------|----------|--------|-----------|
# | 25    | 50000    | Male   | Yes       |
# | 30    | 60000    | Female | No        |
# | 28    | 52000    | Female | Yes       |
#
# - **Age**: Numerical
# - **Salary**: Numerical
# - **Gender**: Categorical
# - **Purchased**: Categorical
#
# ### ✅ **Step 2: Choose the Right Analysis Method Based on Variable Types**
#
# | **Variable Type**       | **Recommended Methods**                             | **Visualization**          |
# |-------------------------|-----------------------------------------------------|---------------------------|
# | Numerical ↔ Numerical    | Correlation, Regression, Scatter Plot              | Scatter Plot, Line Plot    |
# | Categorical ↔ Numerical  | Grouped Summary, Box Plot, Bar Chart               | Box Plot, Bar Chart        |
# | Categorical ↔ Categorical| Crosstab, Chi-Square Test, Heatmap                 | Heatmap, Stacked Bar Chart |
#
#
#
# ## 🧪 **Bivariate Analysis Methods (with Code Examples)**
#
#
#
# ### 📊 **1. Numerical ↔ Numerical: Use Correlation & Scatter Plot**
#
# #### **Goal:** Check if two numerical variables are related.
#
# ✅ **Steps:**
# 1. Calculate **correlation**.
# 2. Visualize with a **scatter plot**.
#
# ```python
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Sample dataset
# data = {
#     'Age': [25, 30, 28, 32, 40],
#     'Salary': [50000, 60000, 52000, 58000, 70000]
# }
# df = pd.DataFrame(data)
#
# # 1. Correlation
# correlation = df.corr()
# print("Correlation Matrix:\n", correlation)
#
# # 2. Scatter Plot
# sns.scatterplot(data=df, x='Age', y='Salary')
# plt.title('Scatter Plot: Age vs. Salary')
# plt.show()
# ```
#
# 📌 **Interpretation:**
# - If the correlation is close to **1**: Strong positive relationship.
# - If the correlation is close to **-1**: Strong negative relationship.
# - If it's close to **0**: No relationship.
#
#
#
# ### 📦 **2. Categorical ↔ Numerical: Use Grouped Summary & Box Plot**
#
# #### **Goal:** Compare numerical values across different categories.
#
# ✅ **Steps:**
# 1. Use **groupby()** to get the summary.
# 2. Visualize with a **box plot** or **bar chart**.
#
# ```python
# # Sample dataset
# data = {
#     'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
#     'Salary': [50000, 60000, 52000, 58000, 70000]
# }
# df = pd.DataFrame(data)
#
# # 1. Grouped Summary
# grouped_summary = df.groupby('Gender')['Salary'].mean()
# print("Grouped Summary:\n", grouped_summary)
#
# # 2. Box Plot
# sns.boxplot(data=df, x='Gender', y='Salary')
# plt.title('Box Plot: Salary by Gender')
# plt.show()
# ```
#
# 📌 **Interpretation:**
# - The box plot shows **distribution**.
# - Check if one category has significantly higher or lower values.
#
#
# ### 🔥 **3. Categorical ↔ Categorical: Use Crosstab & Heatmap**
#
# #### **Goal:** See how two categories relate.
#
# ✅ **Steps:**
# 1. Use **crosstab()** to create a contingency table.
# 2. Visualize with a **heatmap**.
#
# ```python
# # Sample dataset
# data = {
#     'Gender': ['Male', 'Female', 'Female', 'Male', 'Female'],
#     'Purchased': ['Yes', 'No', 'Yes', 'No', 'Yes']
# }
# df = pd.DataFrame(data)
#
# # 1. Crosstab
# crosstab = pd.crosstab(df['Gender'], df['Purchased'])
# print("Crosstab:\n", crosstab)
#
# # 2. Heatmap
# sns.heatmap(crosstab, annot=True, cmap='Blues')
# plt.title('Heatmap: Gender vs. Purchased')
# plt.show()
# ```
#
# 📌 **Interpretation:**
# - The heatmap shows **frequency**.
# - You can see patterns like whether one gender purchases more frequently.
#
#
# ### 📈 **Bonus Tips for Effective Bivariate Analysis**
# 1. **Check for outliers** using box plots.
# 2. Use **log transformation** if the data is skewed.
# 3. Use **scatter plots** for quick insights and **correlation heatmaps** for a bigger picture.
#
#
# ## ✅ **Summary of Bivariate Analysis Steps**
# | **Step**                 | **What to Do**                                     | **Example Tools**            |
# |--------------------------|----------------------------------------------------|-----------------------------|
# | 1. Identify variable types | Check if the variables are numerical or categorical | `df.dtypes`                 |
# | 2. Choose the right method | Use correlation, crosstab, groupby based on types | Correlation, Crosstab       |
# | 3. Visualize the data      | Use scatter plots, box plots, or heatmaps         | `sns.scatterplot()`, `sns.boxplot()` |
#
#
# ### 🎯 **Final Tip:** Automate Bivariate Analysis with Pandas Profiling
#
# For quick EDA, use **pandas-profiling** to generate a complete report:
#
# ```python
# # Install pandas-profiling if not already installed
# !pip install pandas-profiling
#
# # Generate profile report
# from pandas_profiling import ProfileReport
#
# profile = ProfileReport(df)
# profile.to_notebook_iframe()
# ```
#
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## (Numerical-Numerical)

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Bivariate

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Multivariate

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
# sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='smoker')
# sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=df,x='total_bill',y='tip',)

# %% [markdown]
# ## (Numerical - Categorical)

# %%
df1=sns.load_dataset('titanic')

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ## 1. Bar-Plot

# %%
sns.barplot(data=df1,x='survived',y='fare')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %% [markdown]
# ## Multivariate

# %%
sns.catplot(data=df1,x='pclass',y='age',hue='sex',kind='bar')

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ## 2. Box-Plot

# %%
sns.boxplot(data=df1,x='sex',y='age')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# ## Mulitvariate

# %%
sns.boxplot(data=df1,x='sex',y='age',hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.catplot(data=df1,x='pclass',y='fare',hue='sex',kind='box')

# %% [markdown]
# ## 3. Kdeplot

# %%
sns.kdeplot(data=df1,x='age',hue='survived')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## (Categorical-Categorical)

# %% [markdown]
# ## 1.Heatmap

# %%
corr = df1.corr()

sns.heatmap(corr,annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
subset = df1[['survived','parch']]
correlation = subset.corr()

# sns.heatmap(data=correlation)
sns.heatmap(data=correlation,annot=True,cmap='coolwarm',fmt='.2f',cbar=True)
# Out:
# <AxesSubplot:>

# %%
df1.groupby('pclass').mean()['survived']*100
# Out:
# pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: survived, dtype: float64

# %%
(df1.groupby('pclass').mean()['survived']*100).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %% [markdown]
# ## 2.ClusterMap

# %%
cl = pd.crosstab(df1['parch'],df1['survived'])

# %%
sns.clustermap(cl)

# %% [markdown]
# ## 3. Pairplot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# ## Lineplot(Numerical-Numerical)

# %%
df3 = sns.load_dataset('flights')

# %%
df3
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df3.groupby('year').sum().reset_index()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(data=df3,x='year',y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## heatmap for time-series data

# %%
corrt = df3.pivot_table(values='passengers',index='month',columns='year')

# %%
corrt
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(16,6))
sns.heatmap(corrt,annot=True,fmt='.2f')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
corr = df.corr()

sns.heatmap(corr,annot=True,fmt='.2f',)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Full code

# %%
# 1. Numerical- Numerical

#scatter-plot bivariate
numerical_columns = ['total_bill','tip','size']

for col in numerical_columns:
    if col != 'tip':
        sns.scatterplot(x=df[col],y=df['tip'])
        plt.title(f"Scatter plot for {col} vs tip")
        plt.xlabel(col)
        plt.ylabel('tip')
        plt.show()
print('-'*50)


#Multivariate
for col in numerical_columns:
    if col != 'tip':
        sns.scatterplot(x=df[col],y=df['tip'],hue=df['sex'])
        plt.title(f"Multivariate Scatter plot for {col} vs tip")
        plt.xlabel(col)
        plt.ylabel('tip')
        plt.show()

# %%
# Numerical - categorical

numerical_cat = ['tip']
categorical_cat = ['sex','smoker','day','time']

#bivariate
for cat in categorical_cat:
    sns.boxplot(x=df[cat],y=df['tip'])
    plt.title(f"Box Plot for {cat} vs tip")
    plt.xlabel(cat)
    plt.ylabel('tip')
    plt.show()

print('-'*50)

#Multivariate
for cat in categorical_cat:
    sns.boxplot(x=df[cat],y=df['tip'],hue=df['sex'])
    plt.title(f"Multivariate Box Plot for {cat} vs tip")
    plt.xlabel(cat)
    plt.ylabel('tip')
    plt.show()

# %%
# categorical - categorical

#Bivariate
sns.pairplot(df)
print('-'*50)

#Multivariate
sns.pairplot(df,hue='sex')


# heatmap
corr = df.corr()
sns.heatmap(corr,annot=True,fmt='.2f')
