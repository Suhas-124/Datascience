# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define a model with Dropout and L2 Regularization
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten 28x28 images
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),  # L2 Regularization
    Dropout(0.3),  # Dropout layer to reduce overfitting
    Dense(512, activation='relu', kernel_regularizer=l2(0.001)),  # L2 Regularization
    Dropout(0.3),  # Dropout layer
    Dense(10, activation='softmax')  # Output layer
])

print(model.summary())

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with Early Stopping
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping])

# Plot training vs validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot Accuracy vs Validation accuracy
plt.plot(history.history['accuracy'],label='accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.6241 - accuracy: 0.9198 - val_loss: 0.3503 - val_accuracy: 0.9616
# Epoch 2/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3854 - accuracy: 0.9452 - val_loss: 0.3333 - val_accuracy: 0.9565
# Epoch 3/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3586 - accuracy: 0.9487 - val_loss: 0.3067 - val_accuracy: 0.9614
# Epoch 4/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3371 - accuracy: 0.9511 - val_loss: 0.2841 - val_accuracy: 0.9647
# Epoch 5/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3303 - accuracy: 0.9510 - val_loss: 0.2797 - val_accuracy: 0.9661
# Epoch 6/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3227 - accuracy: 0.9517 - val_loss: 0.2848 - val_accuracy: 0.9651
# Epoch 7/50
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3163 - accuracy: 0.9527 - val_loss: 0.2963 - val_accuracy: 0.9594
# Epoch 8/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3112 - accuracy: 0.9527 - val_loss: 0.2520 - val_accuracy: 0.9705
# Epoch 9/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3047 - accuracy: 0.9545 - val_loss: 0.2777 - val_accuracy: 0.9622
# Epoch 10/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3037 - accuracy: 0.9530 - val_loss: 0.2668 - val_accuracy: 0.9652
# Epoch 11/50
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3031 - accuracy: 0.9537 - val_loss: 0.2519 - val_accuracy: 0.9686
# Epoch 12/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3004 - accuracy: 0.9533 - val_loss: 0.2679 - val_accuracy: 0.9659
# Epoch 13/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2986 - accuracy: 0.9546 - val_loss: 0.2756 - val_accuracy: 0.9607
# Epoch 14/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2966 - accuracy: 0.9544 - val_loss: 0.2573 - val_accuracy: 0.9646
# Epoch 15/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3015 - accuracy: 0.9527 - val_loss: 0.2524 - val_accuracy: 0.9676
# Epoch 16/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2979 - accuracy: 0.9535 - val_loss: 0.2504 - val_accuracy: 0.9667
# Epoch 17/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2954 - accuracy: 0.9540 - val_loss: 0.2542 - val_accuracy: 0.9688
# Epoch 18/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2952 - accuracy: 0.9530 - val_loss: 0.2511 - val_accuracy: 0.9685
# Epoch 19/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2931 - accuracy: 0.9548 - val_loss: 0.2407 - val_accuracy: 0.9679
# Epoch 20/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2918 - accuracy: 0.9546 - val_loss: 0.2443 - val_accuracy: 0.9659
# Epoch 21/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2909 - accuracy: 0.9545 - val_loss: 0.2385 - val_accuracy: 0.9696
# Epoch 22/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2931 - accuracy: 0.9532 - val_loss: 0.2407 - val_accuracy: 0.9697
# Epoch 23/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2922 - accuracy: 0.9541 - val_loss: 0.2508 - val_accuracy: 0.9664
# Epoch 24/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2858 - accuracy: 0.9565 - val_loss: 0.2349 - val_accuracy: 0.9698
# Epoch 25/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2875 - accuracy: 0.9552 - val_loss: 0.2413 - val_accuracy: 0.9690
# Epoch 26/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2863 - accuracy: 0.9550 - val_loss: 0.2557 - val_accuracy: 0.9645
# Epoch 27/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2881 - accuracy: 0.9541 - val_loss: 0.2328 - val_accuracy: 0.9715
# Epoch 28/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2885 - accuracy: 0.9538 - val_loss: 0.2271 - val_accuracy: 0.9724
# Epoch 29/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2857 - accuracy: 0.9551 - val_loss: 0.2448 - val_accuracy: 0.9669
# Epoch 30/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2870 - accuracy: 0.9544 - val_loss: 0.2269 - val_accuracy: 0.9722
# Epoch 31/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2833 - accuracy: 0.9549 - val_loss: 0.2332 - val_accuracy: 0.9707
# Epoch 32/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2851 - accuracy: 0.9548 - val_loss: 0.2375 - val_accuracy: 0.9705
# Epoch 33/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2876 - accuracy: 0.9542 - val_loss: 0.2294 - val_accuracy: 0.9714
# Epoch 34/50
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2832 - accuracy: 0.9553 - val_loss: 0.2299 - val_accuracy: 0.9702
# Epoch 35/50
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2844 - accuracy: 0.9549 - val_loss: 0.2289 - val_accuracy: 0.9703

# %% [markdown]
# ## Prediction

# %%
import numpy as np
# Prediction

single_image = x_test[0].reshape(1,28,28)
single_prediction = model.predict(single_image)
predicted_class = np.argmax(single_prediction)

print(predicted_class)
# Out:
# 7

# %%
plt.imshow(x_test[0],cmap='gray')
