# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/suhas/Desktop/office/Data Science/Notes/Data Analysis/Data/placement.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.scatterplot(x=df['cgpa'],y=df['placement_exam_marks'],hue=df['placed'])
# Out:
# <AxesSubplot:xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron

p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-25.65,  -8.  ]])

# %%
p.intercept_
# Out:
# array([-15.])

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X.values,y.values,clf=p,legend=2)
# Out:
# /home/suhas/master_dataklout/venv/lib/python3.6/site-packages/mlxtend/plotting/decision_regions.py:246: UserWarning: No contour levels were found within the data range.
#   antialiased=True)
# <AxesSubplot:>
