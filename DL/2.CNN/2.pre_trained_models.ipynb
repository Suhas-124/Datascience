# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions

# %%
model = ResNet50(weights='imagenet')

# %%
import numpy as np
image_info = '/content/chim.jpeg'
img = image.load_img(image_info,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
import cv2
import matplotlib.pyplot as plt
test_img = cv2.imread('/content/chim.jpeg')
plt.imshow(test_img)
plt.show()

# %%
preds = model.predict(x)
print('Prediction:',decode_predictions(preds,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Prediction: [('n02481823', 'chimpanzee', 0.98397726), ('n02483708', 'siamang', 0.012448831), ('n02486261', 'patas', 0.0010829278)]
